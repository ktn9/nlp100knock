# %% [markdown]
# f = open('neko.txt')
# txt = f.read()
# f.close()

# %%
import sys
import MeCab
m = MeCab.Tagger ("mecab-ipadic-neologd")

# %%
def parse_mecab(block):
    res = []
    
    for line in block.split('\n'):
        if line == '':
            return res
        (surface, node) = line.split('\t')
        pos,pos1,_,_,_,_,base,*_ = node.split(",")
        lineDict = {
            'surface': surface,
            'base': base,
            'pos': pos,
            'pos1': pos1
        }
        if surface == "\u3000":
            continue
        res.append(lineDict)

with open("neko.txt.mecab",mode="rt",encoding="utf-8") as f:
    txt = f.read().split("EOS\n")

txt = list(filter(lambda x: x!= "",txt))
doc = [parse_mecab(block) for block in txt if len(block) != 0]

doc = [i for i in doc if i != []]

# %% [markdown]
# txt = txt.replace("\u3000","")

# %% [markdown]
# txt = [i for i in txt.split("\n") if len(i) > 1]

# %% [markdown]
# doc = []
#
# for i in txt:
#     node = m.parseToNode(i)
#     sent = []
#     while node:
#         d = dict()
#         surface = node.surface
#         if len(node.feature.split(",")) == 6:
#             pos,pos1,*_ = node.feature.split(",")
#             base = pos
#         else:
#             pos,pos1,_,_,_,_,base,_,*_ = node.feature.split(",")
#         d["surface"] = surface
#         d["pos"] = pos
#         d["pos1"] = pos1
#         d["base"]= base
#         sent.append(d)
#         node = node.next
#     doc.append(sent)

# %%
verb_surface = set()

for i in doc:
    suit_verb = list(filter(lambda x: x["pos"] == "動詞",i))
    verb_surface = verb_surface|set(map(lambda x: x["surface"],suit_verb))

# %%
verb_surface
# Out:
# {'続い',
#  '舂き',
#  '陥ら',
#  '伝わっ',
#  '吐く',
#  '裂き',
#  'いる',
#  '捏ね',
#  '掻きむしる',
#  '通り抜ける',
#  '在る',
#  '抛り出し',
#  '已む',
#  '引き籠る',
#  '極っ',
#  '押し込ん',
#  '磨りあげ',
#  '抱え',
#  '掛ら',
#  '振り廻し',
#  '言い棄て',
#  'まかり越し',
#  '抱く',
#  '片付け',
#  '重なっ',
#  '云い放つ',
#  'あたっ',
#  'くっ',
#  '飾っ',
#  '差し支える',
#  '害し',
#  '候',
#  '立て籠っ',
#  '責める',
#  '減る',
#  'つっかけ',
#  'いざっ',
#  'やろう',
#  '去る',
#  '借り',
#  '問い',
#  '分れ',
#  'かわら',
#  '防ぐ',
#  '載せる',
#  '呼ばわり',
#  '見知り',
#  '称し',
#  'すかし',
#  '覗き込み',
#  '施こ',
#  '懸かり',
#  '思い込ん',
#  '了る',
#  '燃え',
#  'つらまえる',
#  'もぐれ',
#  '投げ入れる',
#  '考げ',
#  'かかる',
#  '続く',
#  '司どっ',
#  '返る',
#  '弾い',
#  'こしらえ',
#  '起こし',
#  '売渡す',
#  '逃げ込む',
#  '止め',
#  '磨る',
#  'あてがう',
#  '惜しめ',
#  'かこつ',
#  '就い',
#  '捉まる',
#  '頼もう',
#  '明け放っ',
#  '構える',
#  'ひやかさ',
#  '引き下がる',
#  '奪い合っ',
#  '出直そう',
#  '流れる',
#  '端折っ',
#  '受合っ',
#  '染め出し',
#  '見詰める',
#  'ふっ',
#  '口走る',
#  '届け',
#  '飛び',
#  '悲しむ',
#  '諦める',
#  '打ち解け',
#  '引き摺り',
#  '熱し',
#  '得る',
#  '講ずる',
#  '退く',
#  '呑み込む',
#  '凌ぐ',
#  '置ける',
#  '断て',
#  '掻き',
#  '陣取っ',
#  '及ん',
#  '吐か',
#  '痛み入っ',
#  '発する',
#  '消そう',
#  '休ま',
#  '泣い',
#  '連ね',
#  '捲き上げ',
#  '浸す',
#  'むけ',
#  'あつかう',
#  'なさ',
#  '吸い込ん',
#  '振い落す',
#  '並ん',
#  'ふるえ',
#  '起こす',
#  '御する',
#  'いただく',
#  '振り落とそう',
#  'しく',
#  '起し',
#  '明けれ',
#  'あらわれ',
#  '踏み潰す',
#  '気取っ',
#  '見すまし',
#  'はずれ',
#  '涸らす',
#  '減っ',
#  'すくっ',
#  '縮まる',
#  '始め',
#  '見上げ',
#  'なれる',
#  '切り開い',
#  '聞き分ける',
#  '胡魔化し',
#  '斬る',
#  '説き落し',
#  '捉まえ',
#  '懸かっ',
#  'もらおう',
#  '具え',
#  '称え',
#  '叱りつける',
#  '見張っ',
#  'つけ加え',
#  '差し控え',
#  '描い',
#  'おろし',
#  '含める',
#  '享け',
#  '勝て',
#  '思い込める',
#  '膨れ',
#  '散らす',
#  '点ける',
#  '持て',
#  '纏める',
#  'つかみ出し',
#  '読みかけ',
#  '付き',
#  '走る',
#  '突き込ん',
#  '吸取り',
#  '書き立て',
#  'かく',
#  '咎めん',
#  '荒立て',
#  '伝っ',
#  '塗っ',
#  '載せ',
#  '盛り込ま',
#  '持つ',
#  '吹き払い',
#  '流れ込む',
#  '廻れ',
#  '貪り',
#  '綴っ',
#  '飛びつき',
#  '振い',
#  '戒め',
#  '結っ',
#  '載っけ',
#  '捕っ',
#  '歩き',
#  '乱れ',
#  '突き廻さ',
#  'くれれ',
#  '見合せ',
#  'つづか',
#  'はめ',
#  '啓し',
#  '許せ',
#  '済し',
#  'あきれ',
#  '寝ぼけ',
#  '記し',
#  '揉み',
#  '手こずっ',
#  'もやる',
#  '言いあらわせ',
#  'まごつい',
#  '極め',
#  '得',
#  '使',
#  'こじ開ける',
#  '詠ん',
#  '嫌う',
#  '着',
#  '入っ',
#  '襲う',
#  '打ち落す',
#  'とろう',
#  '了り',
#  '踏張る',
#  '集まる',
#  '融け',
#  '成る',
#  '取り掛る',
#  'かしこまり',
#  '察する',
#  '異なる',
#  '下ろし',
#  '積みかさね',
#  '馴らし',
#  'さか',
#  '適し',
#  'うたう',
#  '驚く',
#  '死ん',
#  '凝らし',
#  '画い',
#  'あび',
#  'つかまっ',
#  '布か',
#  '落ちれ',
#  '乗り込ん',
#  'やめよう',
#  '廃する',
#  'かぶせ',
#  '返さ',
#  '引っ繰り返し',
#  '取り寄せる',
#  'あきらめ',
#  '蹲踞まり',
#  '怒ら',
#  '包む',
#  '罹る',
#  'ひねくっ',
#  '戴く',
#  '食み出し',
#  '入り込ん',
#  '逢う',
#  '張付け',
#  '出掛ける',
#  '浴びせ',
#  '戻す',
#  'こすりつけ',
#  '出会わし',
#  'ならべる',
#  '考え出そう',
#  '叫ん',
#  '歩い',
#  '従え',
#  '逆っ',
#  '起つ',
#  '去っ',
#  '褒め',
#  '立て通す',
#  '浮く',
#  '生い',
#  '開い',
#  '潜り',
#  '罵る',
#  '繰返し',
#  '潜れ',
#  '引張っ',
#  '溜ら',
#  '張りたて',
#  '外し',
#  '響き',
#  '曇っ',
#  'だて',
#  '撫でおろす',
#  '引き返し',
#  '付',
#  '生き過ぎ',
#  '持ち上がっ',
#  '雑ぜ',
#  '応える',
#  '嘲ける',
#  '来よう',
#  '得れ',
#  'ねじる',
#  'いき',
#  '進もう',
#  '引き続い',
#  '愧じ',
#  '睨みつける',
#  '瘠せ',
#  '願わく',
#  '併せ',
#  '取り巻い',
#  '枯れ',
#  'なぐる',
#  'かける',
#  '転がり',
#  '取除け',
#  '過ぎよう',
#  '叩い',
#  '取払っ',
#  '廻っ',
#  '形どっ',
#  'つん',
#  '溜め',
#  '馳け込ん',
#  'たた',
#  'こすり',
#  '押し',
#  '寝転ろ',
#  '奉る',
#  'うて',
#  '笑っ',
#  '舞い込む',
#  '果せる',
#  '借す',
#  '坐っ',
#  '数え',
#  '焼い',
#  '掉り立て',
#  '燻っ',
#  '潰れ',
#  'のぼせる',
#  '蹴ら',
#  '癒ら',
#  'がす',
#  'はね',
#  '吹き出す',
#  '受け取り',
#  'つかえる',
#  'わける',
#  '癒る',
#  '積み込ま',
#  '当っ',
#  '得ん',
#  '察せ',
#  '洗え',
#  '切り付ける',
#  '聴い',
#  '引く',
#  '下げ',
#  '覚っ',
#  '困ら',
#  '遊ばせ',
#  '茂っ',
#  'なやん',
#  '属する',
#  '移る',
#  '及ば',
#  '富ん',
#  '引こう',
#  'きせ',
#  '割り切れ',
#  'ぶら下がっ',
#  '衒い',
#  '流れだし',
#  'すみ',
#  '近付い',
#  '藉り',
#  '曲る',
#  'ほり',
#  'うたい',
#  '切らし',
#  'いりゃ',
#  'すれ',
#  'なげ込ん',
#  'うつし',
#  '致す',
#  '生ぜ',
#  '立ち上がる',
#  'むく',
#  '泣か',
#  '向け',
#  '認め',
#  'あきらめる',
#  'はちきれ',
#  'つき',
#  '裏返し',
#  'おくっ',
#  '嚇かせ',
#  'いただきゃ',
#  '剥げる',
#  'しめつける',
#  '促し',
#  '押し返し',
#  'かむ',
#  'もぐる',
#  '賞める',
#  'かから',
#  '切ら',
#  '食べ',
#  '取りとめ',
#  '曲っ',
#  '進ん',
#  '生ずる',
#  'やれ',
#  'とまっ',
#  '承わる',
#  '刻し',
#  '評する',
#  '離れ',
#  '思う',
#  '覗き込む',
#  '舞い下り',
#  '行っ',
#  'ともっ',
#  '存し',
#  'こぼす',
#  '判ぜ',
#  '渡す',
#  '関せ',
#  '悟り',
#  '打ち殺す',
#  '食わせ',
#  '見よう',
#  'まじり',
#  '逆立て',
#  '為し',
#  '追付こう',
#  'もっ',
#  '盗ら',
#  'まわる',
#  '掘り',
#  'しめる',
#  '踊っ',
#  '退治る',
#  'しまおう',
#  '覗い',
#  '捻り出し',
#  '曝く',
#  '拝する',
#  '化する',
#  '追い懸ける',
#  '起せ',
#  '叩き上げ',
#  '終り',
#  '犯さ',
#  'しい',
#  '織り出し',
#  '懸ら',
#  '決しよう',
#  '足ら',
#  '角張っ',
#  '巻き納め',
#  '叩く',
#  '乞う',
#  '見上げる',
#  '追い廻し',
#  '弾き出す',
#  'さえ',
#  'コセつく',
#  '糅',
#  '知り',
#  '凝り固まっ',
#  '擲つ',
#  '覚え',
#  '光る',
#  '下がれ',
#  '吊ら',
#  'ささ',
#  '飛び下りる',
#  '抜く',
#  '収める',
#  '受取る',
#  'いう',
#  'すい',
#  'はなす',
#  '願い',
#  'うる',
#  '損する',
#  '見出す',
#  'いろ',
#  '澄まし',
#  '突込ん',
#  '拵らえ',
#  '隠れ',
#  '仕込む',
#  'ゆる',
#  '惹い',
#  '聞き噛っ',
#  '聴き',
#  '退治',
#  '決せ',
#  'であるく',
#  '目さ',
#  '候わ',
#  '書き',
#  'かしこまっ',
#  '洩れ',
#  '感じ入る',
#  'いいかけ',
#  '尾け',
#  'まくっ',
#  'だす',
#  'ゆか',
#  '逢わ',
#  '捉え',
#  '漂う',
#  '通ら',
#  '注す',
#  'あらわす',
#  '免かれ',
#  '掻い込ん',
#  '掛ける',
#  '延べ',
#  '突き付け',
#  '勝ち',
#  '重ねる',
#  '見付かる',
#  '明い',
#  '詰め込ん',
#  '彫っ',
#  '問い返す',
#  'じゃらし',
#  '仕ら',
#  '造っ',
#  '生れる',
#  '促がし',
#  'たべる',
#  'かかわる',
#  '買っ',
#  'たまい',
#  '比すれ',
#  '擦っ',
#  '背い',
#  '転がれ',
#  '渡る',
#  '付い',
#  '飛び込ま',
#  '承わっ',
#  '損ね',
#  'あらわせ',
#  '語り',
#  '踊ら',
#  '天降る',
#  'あったまり',
#  'よん',
#  '並外れ',
#  'いたたまれ',
#  'めぐらし',
#  '着せる',
#  '告げん',
#  '吹き込む',
#  'あがり',
#  '引っ張り',
#  '勝とう',
#  '捻る',
#  'ふくれ',
#  '産まれ',
#  '足り',
#  'おどかさ',
#  '撰り',
#  '急い',
#  '帰れ',
#  'のしかかっ',
#  '着換え',
#  'ねじ伏せる',
#  '出来れ',
#  '張り付け',
#  'ひく',
#  '練りあるく',
#  'からげる',
#  '買い',
#  'あやまれ',
#  '見届け',
#  '洩らさ',
#  'わかる',
#  '這い出そう',
#  '投ぜ',
#  '詰まら',
#  '行き詰る',
#  '祭り込ん',
#  '好ま',
#  '下さっ',
#  'いやし',
#  '持ち上げ',
#  '据え',
#  '持ち上げる',
#  '跳ね返し',
#  '撫でる',
#  'とろけ',
#  '失せる',
#  '願おう',
#  '威張る',
#  '弄し',
#  '売り飛ばし',
#  'つつま',
#  '引き受け',
#  '経',
#  '剥がれ',
#  'やり',
#  '働か',
#  '乱れ合う',
#  '企だて',
#  '引っ込まし',
#  '打ち殺し',
#  '落す',
#  '驚い',
#  '届く',
#  '這入る',
#  '受け合わ',
#  '取り払う',
#  '眩む',
#  '飼わ',
#  '有り',
#  '見えよう',
#  '捏ね上げ',
#  'ねじ上げ',
#  '立ち行か',
#  '見違える',
#  '飲み',
#  'したがっ',
#  'はずさ',
#  '号し',
#  'あれ',
#  '与え',
#  'づく',
#  'ほのめかす',
#  '施す',
#  'づい',
#  'もたし',
#  '追払っ',
#  '出さ',
#  'あがる',
#  'かかえ',
#  '教えろ',
#  'きめ込む',
#  '捧ぐ',
#  'はらっ',
#  '近付く',
#  '描き出し',
#  '成り',
#  '追い詰め',
#  '動ずる',
#  '差し出し',
#  '冷め',
#  '通り抜けよう',
#  '復し',
#  '掛れ',
#  '忍び込ん',
#  '与うる',
#  'かさん',
#  '亡くなり',
#  '見つかり',
#  '仰せ',
#  '延び',
#  '欠く',
#  '彩っ',
#  'すくい出し',
#  '忍び込む',
#  '惹く',
#  'おっしゃろう',
#  '敷き',
#  '磨い',
#  '取る',
#  '撚り',
#  '間違っ',
#  'ころがり',
#  '劃し',
#  '懸り',
#  '出せる',
#  '産する',
#  '承ら',
#  'もとめ',
#  'あらわれる',
#  '期する',
#  'しゃべらし',
#  '言い',
#  '溶かし込ん',
#  '出逢っ',
#  '直っ',
#  '活かす',
#  '入り乱れ',
#  '填め',
#  '接い',
#  'ゆく',
#  '敲い',
#  '戴い',
#  'であるけ',
#  '張り切れ',
#  '戻る',
#  'つけよう',
#  '刺し通し',
#  '於け',
#  'いよう',
#  '洒落れ',
#  '尽き',
#  '頼ん',
#  'ありゃ',
#  '浴し',
#  '植え付け',
#  '張り詰め',
#  '関する',
#  'いら',
#  '端折り',
#  'わい',
#  '跳ねのけ',
#  '撰っ',
#  '磨り潰し',
#  '妨げ',
#  '頻り',
#  '降る',
#  '及ぼう',
#  '遠のい',
#  'つぐ',
#  '落ちつか',
#  'かすん',
#  '得ろ',
#  '済ます',
#  '繰り返さ',
#  '喰い',
#  '鑑みる',
#  '聞き糺し',
#  '忘れろ',
#  '打た',
#  '弄する',
#  '引き掻く',
#  'もぐり',
#  '浴びる',
#  'ひっくり返し',
#  '苦しめん',
#  '捲く',
#  '試し',
#  '顧み',
#  '漕ぎ付け',
#  '威張っ',
#  'あら',
#  '有す',
#  'しくじっ',
#  '呼びかけ',
#  '着換える',
#  '逃げ',
#  '出せ',
#  'くれん',
#  '担が',
#  '踏ん',
#  '振り上げ',
#  '逆上せ',
#  '噛む',
#  'のさばり出',
#  'しゃがん',
#  '整っ',
#  '救い出し',
#  '着る',
#  '焦る',
#  '守ら',
#  '図ら',
#  'しゃべり',
#  '語る',
#  '引き直し',
#  '打ち出し',
#  '聞きつけ',
#  '縮め',
#  '撲て',
#  'はじめる',
#  '盗ま',
#  'くべる',
#  '通ずる',
#  '噛ま',
#  '恋い',
#  '顧みる',
#  '見受け',
#  '振っ',
#  '陥る',
#  '上り込ん',
#  '戦っ',
#  '漲らす',
#  '巻き付け',
#  '拭き込ん',
#  '困っ',
#  '上がろう',
#  '渡っ',
#  'つまら',
#  '向う',
#  '映ずる',
#  '疑わ',
#  '演ずる',
#  '歩行い',
#  '舞い戻っ',
#  '抱い',
#  '割り切れる',
#  '割き',
#  '取り',
#  'おけ',
#  'あらわし',
#  '聞かし',
#  '住め',
#  'ほてっ',
#  '鳴か',
#  '儲け',
#  '追いかけ',
#  '引き抜く',
#  '聞か',
#  '狼狽え',
#  '突き出し',
#  '足し',
#  '改めれ',
#  '伝わる',
#  '握ろう',
#  '引っ張る',
#  '挑む',
#  'ける',
#  '欺す',
#  '感じる',
#  '考え出し',
#  '動こう',
#  'さし',
#  '舞い込ん',
#  '反し',
#  '申し込ま',
#  '罹っ',
#  '見計らっ',
#  '中っ',
#  '覆せ',
#  '這い出す',
#  '引か',
#  '燃える',
#  '胡麻化そう',
#  '驚ろく',
#  '貼っ',
#  'はりつけ',
#  '捕る',
#  '助かり',
#  '釣れ',
#  '鳴らさ',
#  '浮ん',
#  '括っ',
#  '吹きつけ',
#  '通り',
#  'やりゃ',
#  '盛っ',
#  '作り上げ',
#  '記する',
#  '済ま',
#  '要する',
#  '退ける',
#  '考え込ん',
#  '転がっ',
#  '途切れ',
#  '飲み込ん',
#  '滑らし',
#  '期す',
#  '伸し',
#  '引き戻し',
#  '割る',
#  '待つ',
#  '身構',
#  '住ん',
#  'やむ',
#  '考える',
#  '伺い',
#  '捕まる',
#  '云わし',
#  '吹き散らし',
#  '知る',
#  '立ち留っ',
#  '落し',
#  '引き据え',
#  'ござら',
#  '持ち',
#  '見計う',
#  '引込ん',
#  '連れ',
#  '告げ',
#  '洩る',
#  '成し',
#  '濁っ',
#  '起っ',
#  '忍ば',
#  '映じ',
#  '働い',
#  '抜',
#  'よごれる',
#  'つくし',
#  '異っ',
#  'くっ付い',
#  '有ろう',
#  '押し寄せ',
#  'おっしゃっ',
#  '忘れ',
#  '平らげ',
#  '光らし',
#  '壊し',
#  '売り',
#  '引きずっ',
#  'おける',
#  '発せ',
#  '祝し',
#  '起す',
#  'たくっ',
#  '備われ',
#  'さばけ',
#  '罵しる',
#  '凝っ',
#  '振り返っ',
#  '伝える',
#  '上る',
#  '組ん',
#  '読み直し',
#  '誂える',
#  '引張る',
#  '争う',
#  '代え',
#  'ごまかす',
#  '飲み込めん',
#  'ふかし',
#  '蒔い',
#  'つい',
#  'いけ',
#  '察し',
#  '引い',
#  'きまっ',
#  '歩み寄っ',
#  '寄こし',
#  '捩じ向く',
#  '造ろう',
#  '洗い',
#  '改まる',
#  '取れ',
#  '隠す',
#  'かくそう',
#  '転じ',
#  'こきゃ',
#  '披い',
#  '横わっ',
#  '込め',
#  '敷か',
#  '迎えれ',
#  'ふくれ返っ',
#  '傾け',
#  '馴れ',
#  '横わり',
#  '帰ろう',
#  '重ね',
#  'むき出し',
#  '退け',
#  '考えつい',
#  '乱す',
#  '転がし',
#  '行く',
#  '出で',
#  '坐し',
#  'ある',
#  '見おろす',
#  '決する',
#  '乗り廻し',
#  'はいり',
#  '古る',
#  '奪い',
#  '心づか',
#  '許す',
#  'もらい',
#  '弁じ立てる',
#  '就き',
#  '申し上げ',
#  '推し',
#  'からまっ',
#  '置き',
#  '見積っ',
#  '引き揚げ',
#  '減り',
#  '問い掛ける',
#  'はやる',
#  'かえ',
#  '罷り',
#  '溯ら',
#  '通り越し',
#  '飛び込み',
#  '申し込ん',
#  '過ぎ去っ',
#  '極まっ',
#  '突立っ',
#  '生え',
#  '息ん',
#  '窺っ',
#  '曲がっ',
#  '引け',
#  '縊り',
#  '打ち遣っ',
#  '飲もう',
#  '踏み',
#  '住む',
#  ...}
