# %%
class Morph:
    def __init__(self,surface,attr):
        self.surface = surface
        self.base = attr[6]
        self.pos = attr[0]
        self.pos1 = attr[1]

# %%
class Chunk:
    def __init__(self,morphs,dst,srcs):
        self.morphs = morphs
        self.dst = dst
        self.srcs = srcs

# %%
with open("ai.ja.txt.parsed",mode="r",encoding="utf-8") as f:
    txt = f.read()
txt = txt.replace("EOS\nEOS\n","EOS\n")

# %%
from collections import defaultdict

res = []
for s in txt.split("EOS\n"):
    sent = []
    src_d = defaultdict(list)

    for line_ind, line in enumerate(s.split("\n")):

        if line == "":
            continue

        elif line[0] == "*":
            morphs = []

            _, ind, dst, *_ = line.split()
            dst = int(dst.replace("D", ""))
            src_d[dst].append(int(ind))

            if ind != 0:
                srcs = src_d[int(ind)]
                chunk = Chunk(morphs, dst, srcs)
                sent.append(chunk)
        else:
            surface, attr = line.split()
            attr = attr.split(",")
            morphs.append(Morph(surface, attr))

    res.append(sent)

# %%
from itertools import combinations
for sent in [res[0]]:
    noun_index = []
    for ind,chunk in enumerate(sent):
        if "名詞" in set([morph.pos for morph in chunk.morphs]):
            noun_index.append(ind)
            
    for i,j in combinations(noun_index,2):
        X_pass = [i]
        Y_pass = [j]
        
        ind = sent[i].dst
        while True:
            if ind == -1:
                break
            else:
                X_pass.append(ind)
                ind = sent[ind].dst
        
        ind = sent[j].dst
        while True:
            if ind == -1:
                break
            else:
                Y_pass.append(ind)
                ind = sent[ind].dst
                
        X_chunk = []
        for morph in sent[i].morphs:
            if morph.pos == "名詞":
                X_chunk.append("X")
            elif morph.pos == "記号":
                continue
            else:
                X_chunk.append(morph.surface)
        
        
        Y_chunk = []
        for morph in sent[j].morphs:
            if morph.pos == "名詞":
                Y_chunk.append("Y")
            elif morph.pos == "記号":
                continue
            else:
                Y_chunk.append(morph.surface)
        
        disp = "".join(X_chunk)
        if j in X_pass:
            for xind in X_pass[1:]:
                if xind == j:
                    break
                disp += ("->" + "".join([morph.surface for morph in sent[xind].morphs if morph.pos != "記号"]))
            disp += ("->" + "".join(Y_chunk))
            
        else:
            for xind in X_pass[1:-1]:
                disp += ("->" + "".join([morph.surface for morph in sent[xind].morphs if morph.pos != "記号"]))
            disp += (" | " + "".join(Y_chunk))
            for yind in Y_pass[1:-1]:
                disp += ("->" + "".join([morph.surface for morph in sent[yind].morphs if morph.pos != "記号"]))
            
            disp += (" | " + "".join([morph.surface for morph in sent[X_pass[-1]].morphs if morph.pos != "記号"]))
            
        print(disp)
# Out:
# XXの->Y
# XXの->ディープラーニング->登場と->登場により->行った | YYの->登場と->登場により->行った | なった
# XXの->ディープラーニング->Yと
# XXの->ディープラーニング->登場と->登場により->行った | YY->以降の->ビッグデータの->登場により->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yの->ビッグデータの->登場により->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYの->登場により->行った | なった
# XXの->ディープラーニング->登場と->Yにより
# XXの->ディープラーニング->登場と->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yを->超えて->浸透して->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yに->浸透して->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yして->行った | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | YY->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYの->プレイヤーも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yも->破り | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yでは | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYYYYYが->到達するなど | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yとして->到達するなど | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYに->到達するなど | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yするなど | なった
# XXの->ディープラーニング->登場と->登場により->行った | Yの->最先端技術と | なった
# XXの->ディープラーニング->登場と->登場により->行った | YYと | なった
# X->登場と->登場により->行った | YYの->登場と->登場により->行った | なった
# X->Yと
# X->登場と->登場により->行った | YY->以降の->ビッグデータの->登場により->行った | なった
# X->登場と->登場により->行った | Yの->ビッグデータの->登場により->行った | なった
# X->登場と->登場により->行った | YYの->登場により->行った | なった
# X->登場と->Yにより
# X->登場と->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# X->登場と->登場により->行った | Yを->超えて->浸透して->行った | なった
# X->登場と->登場により->行った | Yに->浸透して->行った | なった
# X->登場と->登場により->行った | Yして->行った | なった
# X->登場と->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# X->登場と->登場により->行った | YY->プレイヤーも->破り | なった
# X->登場と->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# X->登場と->登場により->行った | YYの->プレイヤーも->破り | なった
# X->登場と->登場により->行った | Yも->破り | なった
# X->登場と->登場により->行った | Yでは | なった
# X->登場と->登場により->行った | YYYYYYが->到達するなど | なった
# X->登場と->登場により->行った | Yとして->到達するなど | なった
# X->登場と->登場により->行った | YYに->到達するなど | なった
# X->登場と->登場により->行った | Yするなど | なった
# X->登場と->登場により->行った | Yの->最先端技術と | なった
# X->登場と->登場により->行った | YYと | なった
# XXの->Yと
# XXの->登場と->登場により->行った | YY->以降の->ビッグデータの->登場により->行った | なった
# XXの->登場と->登場により->行った | Yの->ビッグデータの->登場により->行った | なった
# XXの->登場と->登場により->行った | YYの->登場により->行った | なった
# XXの->登場と->Yにより
# XXの->登場と->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# XXの->登場と->登場により->行った | Yを->超えて->浸透して->行った | なった
# XXの->登場と->登場により->行った | Yに->浸透して->行った | なった
# XXの->登場と->登場により->行った | Yして->行った | なった
# XXの->登場と->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | YY->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | YYの->プレイヤーも->破り | なった
# XXの->登場と->登場により->行った | Yも->破り | なった
# XXの->登場と->登場により->行った | Yでは | なった
# XXの->登場と->登場により->行った | YYYYYYが->到達するなど | なった
# XXの->登場と->登場により->行った | Yとして->到達するなど | なった
# XXの->登場と->登場により->行った | YYに->到達するなど | なった
# XXの->登場と->登場により->行った | Yするなど | なった
# XXの->登場と->登場により->行った | Yの->最先端技術と | なった
# XXの->登場と->登場により->行った | YYと | なった
# Xと->登場により->行った | YY->以降の->ビッグデータの->登場により->行った | なった
# Xと->登場により->行った | Yの->ビッグデータの->登場により->行った | なった
# Xと->登場により->行った | YYの->登場により->行った | なった
# Xと->Yにより
# Xと->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# Xと->登場により->行った | Yを->超えて->浸透して->行った | なった
# Xと->登場により->行った | Yに->浸透して->行った | なった
# Xと->登場により->行った | Yして->行った | なった
# Xと->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xと->登場により->行った | YY->プレイヤーも->破り | なった
# Xと->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xと->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xと->登場により->行った | YYの->プレイヤーも->破り | なった
# Xと->登場により->行った | Yも->破り | なった
# Xと->登場により->行った | Yでは | なった
# Xと->登場により->行った | YYYYYYが->到達するなど | なった
# Xと->登場により->行った | Yとして->到達するなど | なった
# Xと->登場により->行った | YYに->到達するなど | なった
# Xと->登場により->行った | Yするなど | なった
# Xと->登場により->行った | Yの->最先端技術と | なった
# Xと->登場により->行った | YYと | なった
# XX->Yの
# XX->以降の->YYの
# XX->以降の->ビッグデータの->Yにより
# XX->以降の->ビッグデータの->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# XX->以降の->ビッグデータの->登場により->行った | Yを->超えて->浸透して->行った | なった
# XX->以降の->ビッグデータの->登場により->行った | Yに->浸透して->行った | なった
# XX->以降の->ビッグデータの->登場により->行った | Yして->行った | なった
# XX->以降の->ビッグデータの->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | YY->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | YYの->プレイヤーも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yも->破り | なった
# XX->以降の->ビッグデータの->登場により->行った | Yでは | なった
# XX->以降の->ビッグデータの->登場により->行った | YYYYYYが->到達するなど | なった
# XX->以降の->ビッグデータの->登場により->行った | Yとして->到達するなど | なった
# XX->以降の->ビッグデータの->登場により->行った | YYに->到達するなど | なった
# XX->以降の->ビッグデータの->登場により->行った | Yするなど | なった
# XX->以降の->ビッグデータの->登場により->行った | Yの->最先端技術と | なった
# XX->以降の->ビッグデータの->登場により->行った | YYと | なった
# Xの->YYの
# Xの->ビッグデータの->Yにより
# Xの->ビッグデータの->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# Xの->ビッグデータの->登場により->行った | Yを->超えて->浸透して->行った | なった
# Xの->ビッグデータの->登場により->行った | Yに->浸透して->行った | なった
# Xの->ビッグデータの->登場により->行った | Yして->行った | なった
# Xの->ビッグデータの->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | YY->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | YYの->プレイヤーも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yも->破り | なった
# Xの->ビッグデータの->登場により->行った | Yでは | なった
# Xの->ビッグデータの->登場により->行った | YYYYYYが->到達するなど | なった
# Xの->ビッグデータの->登場により->行った | Yとして->到達するなど | なった
# Xの->ビッグデータの->登場により->行った | YYに->到達するなど | なった
# Xの->ビッグデータの->登場により->行った | Yするなど | なった
# Xの->ビッグデータの->登場により->行った | Yの->最先端技術と | なった
# Xの->ビッグデータの->登場により->行った | YYと | なった
# XXの->Yにより
# XXの->登場により->行った | YYの->流行を->超えて->浸透して->行った | なった
# XXの->登場により->行った | Yを->超えて->浸透して->行った | なった
# XXの->登場により->行った | Yに->浸透して->行った | なった
# XXの->登場により->行った | Yして->行った | なった
# XXの->登場により->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# XXの->登場により->行った | YY->プレイヤーも->破り | なった
# XXの->登場により->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->登場により->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->登場により->行った | YYの->プレイヤーも->破り | なった
# XXの->登場により->行った | Yも->破り | なった
# XXの->登場により->行った | Yでは | なった
# XXの->登場により->行った | YYYYYYが->到達するなど | なった
# XXの->登場により->行った | Yとして->到達するなど | なった
# XXの->登場により->行った | YYに->到達するなど | なった
# XXの->登場により->行った | Yするなど | なった
# XXの->登場により->行った | Yの->最先端技術と | なった
# XXの->登場により->行った | YYと | なった
# Xにより->行った | YYの->流行を->超えて->浸透して->行った | なった
# Xにより->行った | Yを->超えて->浸透して->行った | なった
# Xにより->行った | Yに->浸透して->行った | なった
# Xにより->行った | Yして->行った | なった
# Xにより->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xにより->行った | YY->プレイヤーも->破り | なった
# Xにより->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xにより->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xにより->行った | YYの->プレイヤーも->破り | なった
# Xにより->行った | Yも->破り | なった
# Xにより->行った | Yでは | なった
# Xにより->行った | YYYYYYが->到達するなど | なった
# Xにより->行った | Yとして->到達するなど | なった
# Xにより->行った | YYに->到達するなど | なった
# Xにより->行った | Yするなど | なった
# Xにより->行った | Yの->最先端技術と | なった
# Xにより->行った | YYと | なった
# XXの->Yを
# XXの->流行を->超えて->浸透して->行った | Yに->浸透して->行った | なった
# XXの->流行を->超えて->Yして
# XXの->流行を->超えて->浸透して->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | YY->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | YYの->プレイヤーも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yも->破り | なった
# XXの->流行を->超えて->浸透して->行った | Yでは | なった
# XXの->流行を->超えて->浸透して->行った | YYYYYYが->到達するなど | なった
# XXの->流行を->超えて->浸透して->行った | Yとして->到達するなど | なった
# XXの->流行を->超えて->浸透して->行った | YYに->到達するなど | なった
# XXの->流行を->超えて->浸透して->行った | Yするなど | なった
# XXの->流行を->超えて->浸透して->行った | Yの->最先端技術と | なった
# XXの->流行を->超えて->浸透して->行った | YYと | なった
# Xを->超えて->浸透して->行った | Yに->浸透して->行った | なった
# Xを->超えて->Yして
# Xを->超えて->浸透して->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | YY->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | YYの->プレイヤーも->破り | なった
# Xを->超えて->浸透して->行った | Yも->破り | なった
# Xを->超えて->浸透して->行った | Yでは | なった
# Xを->超えて->浸透して->行った | YYYYYYが->到達するなど | なった
# Xを->超えて->浸透して->行った | Yとして->到達するなど | なった
# Xを->超えて->浸透して->行った | YYに->到達するなど | なった
# Xを->超えて->浸透して->行った | Yするなど | なった
# Xを->超えて->浸透して->行った | Yの->最先端技術と | なった
# Xを->超えて->浸透して->行った | YYと | なった
# Xに->Yして
# Xに->浸透して->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xに->浸透して->行った | YY->プレイヤーも->破り | なった
# Xに->浸透して->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xに->浸透して->行った | YYの->プレイヤーも->破り | なった
# Xに->浸透して->行った | Yも->破り | なった
# Xに->浸透して->行った | Yでは | なった
# Xに->浸透して->行った | YYYYYYが->到達するなど | なった
# Xに->浸透して->行った | Yとして->到達するなど | なった
# Xに->浸透して->行った | YYに->到達するなど | なった
# Xに->浸透して->行った | Yするなど | なった
# Xに->浸透して->行った | Yの->最先端技術と | なった
# Xに->浸透して->行った | YYと | なった
# Xして->行った | YYから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | YYにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | Yした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | Yが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | YYYである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | Yなどの->トップ棋士->プレイヤーも->破り | なった
# Xして->行った | YY->プレイヤーも->破り | なった
# Xして->行った | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xして->行った | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xして->行った | YYの->プレイヤーも->破り | なった
# Xして->行った | Yも->破り | なった
# Xして->行った | Yでは | なった
# Xして->行った | YYYYYYが->到達するなど | なった
# Xして->行った | Yとして->到達するなど | なった
# Xして->行った | YYに->到達するなど | なった
# Xして->行った | Yするなど | なった
# Xして->行った | Yの->最先端技術と | なった
# Xして->行った | YYと | なった
# XXから->YYにかけて
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXから->2017年にかけて->Yした
# XXから->2017年にかけて->導入した->Yが
# XXから->2017年にかけて->導入した->AIが->YYYである
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->Yなどの
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->YY
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->Yも
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# XXから->2017年にかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | なった
# XXにかけて->Yした
# XXにかけて->導入した->Yが
# XXにかけて->導入した->AIが->YYYである
# XXにかけて->導入した->AIが->完全情報ゲームである->Yなどの
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->YY
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->Yも
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# XXにかけて->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# Xを->Yした
# Xを->導入した->Yが
# Xを->導入した->AIが->YYYである
# Xを->導入した->AIが->完全情報ゲームである->Yなどの
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->YY
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->Yも
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# Xを->導入した->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# Xした->Yが
# Xした->AIが->YYYである
# Xした->AIが->完全情報ゲームである->Yなどの
# Xした->AIが->完全情報ゲームである->囲碁などの->YY
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->Yも
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# Xした->AIが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# Xが->YYYである
# Xが->完全情報ゲームである->Yなどの
# Xが->完全情報ゲームである->囲碁などの->YY
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->Yも
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# Xが->完全情報ゲームである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# XXXである->Yなどの
# XXXである->囲碁などの->YY
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# XXXである->囲碁などの->トップ棋士->Yも
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | Yでは | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# XXXである->囲碁などの->トップ棋士->プレイヤーも->破り | YYと | なった
# Xなどの->YY
# Xなどの->トップ棋士->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# Xなどの->トップ棋士->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# Xなどの->トップ棋士->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# Xなどの->トップ棋士->Yも
# Xなどの->トップ棋士->プレイヤーも->破り | Yでは | なった
# Xなどの->トップ棋士->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# Xなどの->トップ棋士->プレイヤーも->破り | Yとして->到達するなど | なった
# Xなどの->トップ棋士->プレイヤーも->破り | YYに->到達するなど | なった
# Xなどの->トップ棋士->プレイヤーも->破り | Yするなど | なった
# Xなどの->トップ棋士->プレイヤーも->破り | Yの->最先端技術と | なった
# Xなどの->トップ棋士->プレイヤーも->破り | YYと | なった
# XX->プレイヤーも->破り | YYYである->ポーカーの->世界トップクラスの->プレイヤーも->破り | なった
# XX->プレイヤーも->破り | Yの->世界トップクラスの->プレイヤーも->破り | なった
# XX->プレイヤーも->破り | YYの->プレイヤーも->破り | なった
# XX->Yも
# XX->プレイヤーも->破り | Yでは | なった
# XX->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XX->プレイヤーも->破り | Yとして->到達するなど | なった
# XX->プレイヤーも->破り | YYに->到達するなど | なった
# XX->プレイヤーも->破り | Yするなど | なった
# XX->プレイヤーも->破り | Yの->最先端技術と | なった
# XX->プレイヤーも->破り | YYと | なった
# XXXである->Yの
# XXXである->ポーカーの->YYの
# XXXである->ポーカーの->世界トップクラスの->Yも
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | Yでは | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | Yとして->到達するなど | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | YYに->到達するなど | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | Yするなど | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | Yの->最先端技術と | なった
# XXXである->ポーカーの->世界トップクラスの->プレイヤーも->破り | YYと | なった
# Xの->YYの
# Xの->世界トップクラスの->Yも
# Xの->世界トップクラスの->プレイヤーも->破り | Yでは | なった
# Xの->世界トップクラスの->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# Xの->世界トップクラスの->プレイヤーも->破り | Yとして->到達するなど | なった
# Xの->世界トップクラスの->プレイヤーも->破り | YYに->到達するなど | なった
# Xの->世界トップクラスの->プレイヤーも->破り | Yするなど | なった
# Xの->世界トップクラスの->プレイヤーも->破り | Yの->最先端技術と | なった
# Xの->世界トップクラスの->プレイヤーも->破り | YYと | なった
# XXの->Yも
# XXの->プレイヤーも->破り | Yでは | なった
# XXの->プレイヤーも->破り | YYYYYYが->到達するなど | なった
# XXの->プレイヤーも->破り | Yとして->到達するなど | なった
# XXの->プレイヤーも->破り | YYに->到達するなど | なった
# XXの->プレイヤーも->破り | Yするなど | なった
# XXの->プレイヤーも->破り | Yの->最先端技術と | なった
# XXの->プレイヤーも->破り | YYと | なった
# Xも->破り | Yでは | なった
# Xも->破り | YYYYYYが->到達するなど | なった
# Xも->破り | Yとして->到達するなど | なった
# Xも->破り | YYに->到達するなど | なった
# Xも->破り | Yするなど | なった
# Xも->破り | Yの->最先端技術と | なった
# Xも->破り | YYと | なった
# Xでは | YYYYYYが->到達するなど | なった
# Xでは | Yとして->到達するなど | なった
# Xでは | YYに->到達するなど | なった
# Xでは | Yするなど | なった
# Xでは | Yの->最先端技術と | なった
# Xでは | YYと | なった
# XXXXXXが->到達するなど | Yとして->到達するなど | なった
# XXXXXXが->到達するなど | YYに->到達するなど | なった
# XXXXXXが->Yするなど
# XXXXXXが->到達するなど | Yの->最先端技術と | なった
# XXXXXXが->到達するなど | YYと | なった
# Xとして->到達するなど | YYに->到達するなど | なった
# Xとして->Yするなど
# Xとして->到達するなど | Yの->最先端技術と | なった
# Xとして->到達するなど | YYと | なった
# XXに->Yするなど
# XXに->到達するなど | Yの->最先端技術と | なった
# XXに->到達するなど | YYと | なった
# Xするなど | Yの->最先端技術と | なった
# Xするなど | YYと | なった
# Xの->YYと

# %%
Y_pass
# Out:
# [13]

# %%
X_pass
# Out:
# [12, 13]
